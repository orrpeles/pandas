# %%
import pandas as pd

# %%
df = pd.read_csv('/home/enumtheworld/Downloads/safecharge_notifications.csv', usecols=['Date', 'Action/recurringType', 'ResultDescription', 'Geo', 'Email', 'amount', 'currency' ])

# %%
df.shape
# Out:
# (96890, 7)

# %%
df.head(6)
# Out:
#          Date Action/recurringType ResultDescription  Geo Email  amount  \
# 0  1/Jun/2021                  NaN               NaN  NaN   NaN     NaN
# 1  1/Jun/2021                  NaN               NaN  NaN   NaN     NaN
# 2  1/Jun/2021                  NaN               NaN  NaN   NaN     NaN
# 3  1/Jun/2021                  NaN               NaN  NaN   NaN     NaN
# 4  1/Jun/2021                  NaN               NaN  NaN   NaN     NaN
# 5  1/Jun/2021                  NaN               NaN  NaN   NaN     NaN
#
#   currency
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5      NaN

# %%
df.isnull().any() ## Where do I have NaaN values?
# Out:
# Date                    False
# Action/recurringType     True
# ResultDescription        True
# Geo                      True
# Email                    True
# amount                   True
# currency                 True
# dtype: bool

# %%
null_columns1 = df.columns[df.isnull().any()] ## How many NaaN values do I have in total?
df[null_columns1].isnull().sum()
# Out:
# Action/recurringType    40304
# ResultDescription       40304
# Geo                     40304
# Email                   40304
# amount                  40304
# currency                40304
# dtype: int64

# %%
df = df.dropna()

# %%
df.head(10)
# Out:
#           Date Action/recurringType         ResultDescription Geo  \
# 8   1/Jun/2021                 Auth              Do not honor  AU
# 10  1/Jun/2021                 Auth                  APPROVED  AU
# 19  1/Jun/2021                 Auth        Insufficient funds  HU
# 22  1/Jun/2021                 Auth                  APPROVED  HU
# 24  1/Jun/2021                 Auth  Exceeds withdrawal limit  HU
# 28  1/Jun/2021                 Auth  Exceeds withdrawal limit  HU
# 35  1/Jun/2021                 Auth                  APPROVED  HU
# 43  1/Jun/2021                 Auth                  APPROVED  PT
# 52  1/Jun/2021                 Auth                  APPROVED  PT
# 61  1/Jun/2021                 Auth                  APPROVED  DE
#
#                                Email  amount currency
# 8           nick_chidiac@hotmail.com     1.0      AUD
# 10          nick_chidiac@hotmail.com     1.0      AUD
# 19                 ktiza32@gmail.com     1.0      EUR
# ...

# %%
df.shape
# Out:
# (56586, 7)

# %%
import datetime

# %%
df['Date'] = pd.to_datetime(df.Date)

# %%
df['Date'].dt.date
# Out:
# 8        2021-06-01
# 10       2021-06-01
# 19       2021-06-01
# 22       2021-06-01
# 24       2021-06-01
# 28       2021-06-01
# 35       2021-06-01
# 43       2021-06-01
# 52       2021-06-01
# 61       2021-06-01
# 63       2021-06-01
# 74       2021-06-01
# 78       2021-06-01
# 80       2021-06-01
# 82       2021-06-01
# 92       2021-06-01
# 98       2021-06-01
# 101      2021-06-01
# 103      2021-06-01
# 109      2021-06-01
# 112      2021-06-01
# 117      2021-06-01
# 119      2021-06-01
# 121      2021-06-01
# 124      2021-06-01
# 126      2021-06-01
# 127      2021-06-01
# 128      2021-06-01
# 129      2021-06-01
# 132      2021-06-01
#             ...
# 96810    2022-02-20
# 96811    2022-02-20
# 96812    2022-02-20
# 96813    2022-02-20
# 96814    2022-02-20
# 96815    2022-02-20
# 96816    2022-02-20
# 96817    2022-02-20
# 96818    2022-02-20
# 96819    2022-02-20
# 96820    2022-02-20
# 96821    2022-02-20
# 96822    2022-02-20
# 96823    2022-02-20
# ...

# %%
filtered_df = df.loc[(df['Date'] >= '2021-07-01')]

# %%
filtered_df.head(10)
# Out:
#            Date Action/recurringType   ResultDescription Geo  \
# 4185 2021-07-01               Credit            APPROVED  CA
# 4186 2021-07-01               Credit            APPROVED  UK
# 4187 2021-07-01               Credit            APPROVED  UK
# 4188 2021-07-01               Credit            APPROVED  CA
# 4190 2021-07-01                 Auth            APPROVED  PT
# 4193 2021-07-01                 Auth            APPROVED  UK
# 4194 2021-07-01                 Sale  Insufficient funds  FR
# 4195 2021-07-01                 Sale        Do not honor  UK
# 4196 2021-07-01                 Sale        Do not honor  FR
# 4197 2021-07-01                 Sale  Insufficient funds  FR
#
#                                  Email  amount currency
# 4185          kathybrown.kmb@gmail.com   38.88      CAD
# 4186       amritsmith39@googlemail.com   28.95      GBP
# 4187       amritsmith39@googlemail.com   28.95      GBP
# 4188           dmlajeunesse1@gmail.com   38.88      CAD
# ...

# %%
filtered_df.tail(5)
# Out:
#             Date Action/recurringType   ResultDescription Geo  \
# 96867 2022-02-20                 Auth            APPROVED  CY
# 96874 2022-02-20                 Auth            APPROVED  UK
# 96878 2022-02-20                 Auth            APPROVED  UK
# 96884 2022-02-21                 Auth            APPROVED  UK
# 96889 2022-02-21                 Auth  Insufficient funds  UK
#
#                             Email  amount currency
# 96867     corinalungu60@gmail.com     1.0      EUR
# 96874       cbrooks2201@gmail.com     1.0      GBP
# 96878            ssearle@mail.com     1.0      GBP
# 96884  avelinosantos501@gmail.com     1.0      GBP
# 96889       borgmaria78@gmail.com     1.0      GBP

# %%
filtered_df['Action/recurringType'].unique().tolist() ## show unique values under Action/RecurringType
# Out:
# ['Credit', 'Auth', 'Sale', 'Void']

# %%
filtered_df = filtered_df[(filtered_df['Action/recurringType'] != 'Credit') 
& (filtered_df['Action/recurringType'] != 'Auth') 
& (filtered_df['Action/recurringType'] != 'Void')] ## get rid of credit, void and auth values

# %%
filtered_df.head(10)
# Out:
#            Date Action/recurringType   ResultDescription Geo  \
# 4194 2021-07-01                 Sale  Insufficient funds  FR
# 4195 2021-07-01                 Sale        Do not honor  UK
# 4196 2021-07-01                 Sale        Do not honor  FR
# 4197 2021-07-01                 Sale  Insufficient funds  FR
# 4198 2021-07-01                 Sale            APPROVED  UK
# 4199 2021-07-01                 Sale  Insufficient funds  UK
# 4200 2021-07-01                 Sale            APPROVED  SI
# 4201 2021-07-01                 Sale        Do not honor  UK
# 4202 2021-07-01                 Sale        Do not honor  UK
# 4203 2021-07-01                 Sale            APPROVED  ES
#
#                                  Email  amount currency
# 4194  jean-marie.rigaut@reseau.sncf.fr   28.95      EUR
# 4195         rosemariaoakley@gmail.com   28.95      GBP
# 4196           salinthierry5@gmail.com   28.95      EUR
# 4197            mjenderson02@gmail.com   28.95      EUR
# ...

# %%
filtered_df['Action/recurringType'].unique().tolist() ## show unique list for column
# Out:
# ['Sale']

# %%
filtered_df.shape
# Out:
# (28511, 7)

# %%
filtered_df['amount'].unique().tolist() ## show unique list for column
# Out:
# [28.95,
#  400.0,
#  650.0,
#  55.0,
#  38.88,
#  27.5,
#  14.47,
#  19.44,
#  200.0,
#  2386.0,
#  199.0,
#  65.0,
#  1193.0,
#  299.0,
#  33.33,
#  16.66,
#  99.5,
#  10.0,
#  1.0]

# %%
filtered_df.loc[filtered_df['amount'] == 1.0] ## who is the user for which amount == 1.0 ?
# Out:
#             Date Action/recurringType ResultDescription Geo  \
# 89035 2022-02-06                 Sale          APPROVED  LT
# 89314 2022-02-07                 Sale          APPROVED  LT
# 89315 2022-02-07                 Sale          APPROVED  LT
# 89316 2022-02-07                 Sale          APPROVED  LT
#
#                     Email  amount currency
# 89035  oksstuff@gmail.com     1.0      EUR
# 89314  oksstuff@gmail.com     1.0      EUR
# 89315  oksstuff@gmail.com     1.0      EUR
# 89316  oksstuff@gmail.com     1.0      EUR

# %%
filtered_df.to_csv('/home/enumtheworld/Downloads/safecharge_notifications_filtered.csv') ## export to target

# %%
import pandas as pd ##Import relevant library and below import database, filter by preferred columns

# %%
df = pd.read_csv('/home/laptop/Downloads/safecharge_notifications.csv', usecols=['Date', 'Action/recurringType', 'ResultDescription', 'Geo', 'Email', 'amount', 'currency' ])

# %%
df.shape
# Out:
# (101826, 7)

# %%
df.head(6)
# Out:
#           Date Action/recurringType             ResultDescription      Geo  \
# 0   4/Nov/2020                  NaN                           NaN      NaN
# 1   4/Nov/2020                  NaN                           NaN      NaN
# 2  16/Nov/2020                 Auth  Mandatory fields are missing      NaN
# 3  16/Nov/2020                  NaN                           NaN      NaN
# 4  16/Nov/2020                 Auth                       Decline  ANDORRA
# 5  16/Nov/2020                  NaN                           NaN      NaN
#
#          Email  amount currency
# 0          NaN     NaN      NaN
# 1          NaN     NaN      NaN
# 2          NaN     0.0      EUR
# 3          NaN     NaN      NaN
# 4  abc@def.net     0.0      EUR
# 5          NaN     NaN      NaN

# %%
df.isnull().any() ## Where do I have NaaN values?
# Out:
# Date                    False
# Action/recurringType     True
# ResultDescription        True
# Geo                      True
# Email                    True
# amount                   True
# currency                 True
# dtype: bool

# %%
    null_columns1 = df.columns[df.isnull().any()] ## How many NaaN values do I have in total?
    df[null_columns1].isnull().sum()
# Out:
# Action/recurringType    42208
# ResultDescription       42198
# Geo                     42199
# Email                   42204
# amount                  42208
# currency                42198
# dtype: int64

# %%
# Out:
#           Date   Time               Type Action/recurringType  ResultCode  \
# 1   4/Nov/2020  12:32                NaN                  NaN         NaN
# 2  16/Nov/2020  11:16            DEPOSIT                 Auth      1136.0
# 3  16/Nov/2020  11:37  CARD_TOKENIZATION                  NaN         0.0
# 4  16/Nov/2020  11:37            DEPOSIT                 Auth         0.0
#
#               ResultDescription      Geo        Email registrationId  Aff  \
# 1                           NaN      NaN          NaN            NaN  NaN
# 2  Mandatory fields are missing      NaN          NaN            NaN  NaN
# 3                           NaN      NaN          NaN            NaN  NaN
# 4                       Decline  ANDORRA  abc@def.net            NaN  NaN
#
#   M-parameter PubId ClickId paymentType  amount currency  \
# 1         NaN   NaN     NaN         NaN     NaN      NaN
# 2         NaN   NaN     NaN      Credit     0.0      EUR
# ...

# %%
df = df.dropna() ## get rid of ALL NaaN values

# %%
df.head(10) ## check NaaN values have disappeared
# Out:
#            Date Action/recurringType  \
# 4   16/Nov/2020                 Auth
# 8   16/Nov/2020                 Auth
# 10  16/Nov/2020                 Auth
# 12  16/Nov/2020                 Auth
# 14  16/Nov/2020                 Auth
# 17  16/Nov/2020                 Auth
# 19  16/Nov/2020                 Auth
# 23  16/Nov/2020                 Auth
# 25  16/Nov/2020                 Auth
# 28  16/Nov/2020                 Auth
#
#                            ResultDescription            Geo        Email  \
# 4                                    Decline        ANDORRA  abc@def.net
# 8                                    Decline         ISRAEL      a@a.net
# 10              External Error in Processing         ISRAEL      a@a.net
# 12                               Lost/Stolen         ISRAEL      a@a.net
# 14                                  APPROVED         ISRAEL      a@a.net
# 17                                  APPROVED         ISRAEL      a@a.net
# ...

# %%
df.shape
# Out:
# (59612, 7)

# %%
import datetime

# %%
df['Date'] = pd.to_datetime(df.Date) ## Date column has been coerced to Date values

# %%
df['Date'].dt.date ## Date to appear as Date only, ommitting the time element
# Out:
# 4         2020-11-16
# 8         2020-11-16
# 10        2020-11-16
# 12        2020-11-16
# 14        2020-11-16
#              ...
# 101809    2022-01-17
# 101816    2022-01-17
# 101821    2022-01-17
# 101823    2022-01-17
# 101825    2022-01-17
# Name: Date, Length: 59612, dtype: object

# %%
filtered_df = df.loc[(df['Date'] >= '2021-07-01')] ## filter datafram from July 1st 2021 onwards

# %%
filtered_df.head(5)
# Out:
#             Date Action/recurringType ResultDescription       Geo  \
# 24719 2021-07-01               Credit          APPROVED    CANADA
# 24720 2021-07-01               Credit          APPROVED        UK
# 24721 2021-07-01               Credit          APPROVED        UK
# 24722 2021-07-01               Credit          APPROVED    CANADA
# 24724 2021-07-01                 Auth          APPROVED  PORTUGAL
#
#                              Email  amount currency
# 24719     kathybrown.kmb@gmail.com   38.88      CAD
# 24720  amritsmith39@googlemail.com   28.95      GBP
# 24721  amritsmith39@googlemail.com   28.95      GBP
# 24722      dmlajeunesse1@gmail.com   38.88      CAD
# 24724           claudio.fac@gnr.pt    1.00      EUR

# %%
filtered_df.tail(5)
# Out:
#              Date Action/recurringType         ResultDescription        Geo  \
# 101809 2022-01-17                 Auth                  APPROVED         UK
# 101816 2022-01-17                 Auth                  APPROVED         UK
# 101821 2022-01-17                 Auth                     ERROR         HU
# 101823 2022-01-17                 Auth  Exceeds withdrawal limit  MACEDONIA
# 101825 2022-01-17                 Auth  Exceeds withdrawal limit  MACEDONIA
#
#                                 Email  amount currency
# 101809       arvindthandi45@gmail.com     1.0      GBP
# 101816   valentinaraduta490@gmail.com     1.0      GBP
# 101821          mahdyred123@gmail.com     1.0      EUR
# 101823  jovanovskamandalova@gmail.com     1.0      EUR
# 101825  jovanovskamandalova@gmail.com     1.0      EUR

# %%
filtered_df2 = filtered_df[:]

# %%
filtered_df2 = filtered_df2[~filtered_df2['Action/recurringType'].isin(['Auth'])] ## Omit the value 'Auth' from DF

# %%
filtered_df2.head(10)
# Out:
#             Date Action/recurringType   ResultDescription     Geo  \
# 24719 2021-07-01               Credit            APPROVED  CANADA
# 24720 2021-07-01               Credit            APPROVED      UK
# 24721 2021-07-01               Credit            APPROVED      UK
# 24722 2021-07-01               Credit            APPROVED  CANADA
# 24728 2021-07-01                 Sale  Insufficient funds      FR
# 24729 2021-07-01                 Sale        Do not honor      UK
# 24730 2021-07-01                 Sale        Do not honor  FRANCE
# 24731 2021-07-01                 Sale  Insufficient funds  FRANCE
# 24732 2021-07-01                 Sale            APPROVED      UK
# 24733 2021-07-01                 Sale  Insufficient funds      UK
#
#                                   Email  amount currency
# 24719          kathybrown.kmb@gmail.com   38.88      CAD
# 24720       amritsmith39@googlemail.com   28.95      GBP
# 24721       amritsmith39@googlemail.com   28.95      GBP
# ...

# %%
filtered_df2.tail(10)
# Out:
#              Date Action/recurringType   ResultDescription Geo  \
# 101743 2022-01-16                 Sale  Insufficient funds  UK
# 101744 2022-01-16                 Sale            APPROVED  UK
# 101745 2022-01-16                 Sale            APPROVED  AU
# 101746 2022-01-16                 Sale            APPROVED  UK
# 101747 2022-01-16                 Sale            APPROVED  UK
# 101748 2022-01-16                 Sale  Insufficient funds  UK
# 101749 2022-01-16                 Sale     Suspected fraud  UK
# 101750 2022-01-16                 Sale  Insufficient funds  UK
# 101751 2022-01-16                 Sale  Insufficient funds  UK
# 101752 2022-01-16                 Sale  Insufficient funds  HU
#
#                               Email  amount currency
# 101743     daddygiggs39@yahoo.co.uk   28.95      GBP
# 101744     grahamspence48@gmail.com   28.95      GBP
# 101745    stuartsowden@yahoo.com.au   55.00      AUD
# 101746          apaterson@gmail.com   28.95      GBP
# ...

# %%
filtered_df2.to_excel('safecharge_notifications_imported.xlsx') ## Export DF to target

# %%
filtered_df2.Geo.unique().tolist() ##unique values
# Out:
# ['CANADA',
#  'UK',
#  'FR',
#  'FRANCE',
#  'SI',
#  'SPAIN',
#  'PORTUGAL',
#  'ITALY',
#  'SWEDEN',
#  'CYPRUS',
#  'PT',
#  'AUSTRALIA',
#  'IT',
#  'SE',
#  'GERMANY',
#  'SLOVENIA',
#  'CY',
#  'HUNGARY',
#  'ES',
#  'IRELAND',
#  'HU',
#  'AU',
#  'CA',
#  'NORWAY',
#  'NO',
#  'UKRAINE',
#  'PHILIPPINES',
#  'MALAYSIA',
#  'SINGAPORE',
#  'PH',
#  'NEW ZEALAND',
#  'NZ',
#  'SLOVAKIA',
#  'DENMARK',
#  'MY',
#  'IE',
#  'US',
#  'UNITED STATES',
#  'BRAZIL',
#  'ROMANIA',
#  'TURKEY',
#  'SAUDI ARABIA',
#  'DK',
#  'CZECH REPUBLIC',
#  'RO',
#  'DE',
#  'LT',
#  'SA',
#  'LV',
#  'LATVIA',
#  'LITHUANIA',
#  'MT',
#  'CROATIA',
#  'HR',
#  'MK',
#  'SK']

# %%
# Out:
# ['Credit', 'Credit', 'Credit', 'Credit', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Credit', 'Credit', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Void', 'Void', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', 'Sale', '
# ...
